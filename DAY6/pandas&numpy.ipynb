# %%
import pandas as pd

# %%
data = pd.read_csv('usgs_earthquakes_2014.csv')
data.head()
# Out:
#                       time   latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       gap     dmin     rms net          id                   updated  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120108 entries, 0 to 120107
# Data columns (total 15 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       120108 non-null  object
#  1   latitude   120108 non-null  float64
#  2   longitude  120108 non-null  float64
#  3   depth      120107 non-null  float64
#  4   mag        120065 non-null  float64
#  5   magType    120065 non-null  object
#  6   nst        59688 non-null   float64
#  7   gap        94935 non-null   float64
#  8   dmin       85682 non-null   float64
#  9   rms        119716 non-null  float64
#  10  net        120108 non-null  object
#  11  id         120108 non-null  object
#  12  updated    120108 non-null  object
#  13  place      120108 non-null  object
#  14  type       120108 non-null  object
# dtypes: float64(8), object(7)
# memory usage: 13.7+ MB

# %%
data['time'] = pd.to_datetime(data['time'].str.strip())

# %%
# Converting to datetime format
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120108 entries, 0 to 120107
# Data columns (total 15 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       120108 non-null  datetime64[ns]
#  1   latitude   120108 non-null  float64
#  2   longitude  120108 non-null  float64
#  3   depth      120107 non-null  float64
#  4   mag        120065 non-null  float64
#  5   magType    120065 non-null  object
#  6   nst        59688 non-null   float64
#  7   gap        94935 non-null   float64
#  8   dmin       85682 non-null   float64
#  9   rms        119716 non-null  float64
#  10  net        120108 non-null  object
#  11  id         120108 non-null  object
#  12  updated    120108 non-null  object
#  13  place      120108 non-null  object
#  14  type       120108 non-null  object
# dtypes: datetime64[ns](1), float64(8), object(6)
# memory usage: 13.7+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120108 entries, 0 to 120107
# Data columns (total 15 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       120108 non-null  datetime64[ns]
#  1   latitude   120108 non-null  float64
#  2   longitude  120108 non-null  float64
#  3   depth      120107 non-null  float64
#  4   mag        120065 non-null  float64
#  5   magType    120065 non-null  object
#  6   nst        59688 non-null   float64
#  7   gap        94935 non-null   float64
#  8   dmin       85682 non-null   float64
#  9   rms        119716 non-null  float64
#  10  net        120108 non-null  object
#  11  id         120108 non-null  object
#  12  updated    120108 non-null  object
#  13  place      120108 non-null  object
#  14  type       120108 non-null  object
# dtypes: datetime64[ns](1), float64(8), object(6)
# memory usage: 13.7+ MB

# %%
data_new = pd.read_csv('usgs_earthquakes_2014.csv', index_col='id')
data_new
# Out:
#                                time   latitude   longitude   depth   mag  \
# id
# ak11155107  2014-01-31 23:53:37.000  60.252000 -152.708100   90.20  1.10
# nn00436847  2014-01-31 23:48:35.452  37.070300 -115.130900    0.00  1.33
# ak11151142  2014-01-31 23:47:24.000  64.671700 -149.252800    7.10  1.30
# ak11151135  2014-01-31 23:30:54.000  63.188700 -148.957500   96.50  0.80
# ci37171541  2014-01-31 23:30:52.210  32.616833 -115.692500   10.59  1.34
# ...                             ...        ...         ...     ...   ...
# ak11453391  2014-12-01 00:10:16.000  60.963900 -146.762900   14.80  3.80
# ak11453395  2014-12-01 00:09:39.000  58.869100 -154.415900  108.40  2.40
# nc72358451  2014-12-01 00:09:25.350  38.843498 -122.825836    2.37  0.43
# ak11453390  2014-12-01 00:05:54.000  65.152100 -148.992000    9.50  0.40
# ak11453389  2014-12-01 00:04:05.000  60.227200 -147.024500    2.50  1.60
#
#            magType  nst     gap      dmin     rms net  \
# id
# ...

# %%
data_new.describe()
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120108 entries, ak11155107 to ak11453389
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       120108 non-null  object
#  1   latitude   120108 non-null  float64
#  2   longitude  120108 non-null  float64
#  3   depth      120107 non-null  float64
#  4   mag        120065 non-null  float64
#  5   magType    120065 non-null  object
#  6   nst        59688 non-null   float64
#  7   gap        94935 non-null   float64
#  8   dmin       85682 non-null   float64
#  9   rms        119716 non-null  float64
#  10  net        120108 non-null  object
#  11  updated    120108 non-null  object
#  12  place      120108 non-null  object
#  13  type       120108 non-null  object
# dtypes: float64(8), object(6)
# memory usage: 13.7+ MB

# %%
data_new['time'] = pd.to_datetime(data_new['time'].str.strip())
data_new['updated'] =  pd.to_datetime(data_new['updated'].str.strip())

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120108 entries, ak11155107 to ak11453389
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       120108 non-null  datetime64[ns]
#  1   latitude   120108 non-null  float64
#  2   longitude  120108 non-null  float64
#  3   depth      120107 non-null  float64
#  4   mag        120065 non-null  float64
#  5   magType    120065 non-null  object
#  6   nst        59688 non-null   float64
#  7   gap        94935 non-null   float64
#  8   dmin       85682 non-null   float64
#  9   rms        119716 non-null  float64
#  10  net        120108 non-null  object
#  11  updated    120108 non-null  datetime64[ns, UTC]
#  12  place      120108 non-null  object
#  13  type       120108 non-null  object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(8), object(4)
# memory usage: 13.7+ MB

# %%
data['magType'].unique()
# Out:
# array(['ml', 'Md', 'mb', 'md', 'Ml', 'H', nan, 'mwr', 'mww', 'mwb',
#        'mb_lg', 'mh', 'mwc', 'Mw', 'mw', 'mblg', 'mc', 'Mb', 'ms_20'],
#       dtype=object)

# %%
data_new['type'].value_counts()
# Out:
# type
# earthquake             118398
# quarry                    751
# quarry blast              677
# mining explosion          226
# anthropogenic event        32
# explosion                  15
# rock burst                  4
# acoustic noise              2
# landslide                   1
# sonicboom                   1
# sonic boom                  1
# Name: count, dtype: int64

# %%
# Earth quake data

data_earthquake = data_new[data_new['type'] == 'earthquake']
data_earthquake
# Out:
#                               time   latitude   longitude   depth   mag  \
# id
# ak11155107 2014-01-31 23:53:37.000  60.252000 -152.708100   90.20  1.10
# nn00436847 2014-01-31 23:48:35.452  37.070300 -115.130900    0.00  1.33
# ak11151142 2014-01-31 23:47:24.000  64.671700 -149.252800    7.10  1.30
# ak11151135 2014-01-31 23:30:54.000  63.188700 -148.957500   96.50  0.80
# ci37171541 2014-01-31 23:30:52.210  32.616833 -115.692500   10.59  1.34
# ...                            ...        ...         ...     ...   ...
# ak11453391 2014-12-01 00:10:16.000  60.963900 -146.762900   14.80  3.80
# ak11453395 2014-12-01 00:09:39.000  58.869100 -154.415900  108.40  2.40
# nc72358451 2014-12-01 00:09:25.350  38.843498 -122.825836    2.37  0.43
# ak11453390 2014-12-01 00:05:54.000  65.152100 -148.992000    9.50  0.40
# ak11453389 2014-12-01 00:04:05.000  60.227200 -147.024500    2.50  1.60
#
#            magType  nst     gap      dmin     rms net  \
# id
# ...

# %%
#Sorted Earthquake data

data_earthquake_sorted = data_earthquake.sort_values('mag', ascending=False)
data_earthquake_sorted[:20]
# Out:
#                               time  latitude  longitude   depth  mag magType  \
# id
# usc000nzvd 2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww
# usc000rki5 2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww
# usc000p27i 2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww
# usc000phx5 2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww
# usb000pr89 2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww
# usc000piqj 2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww
# usb000slwn 2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww
# usb000pq41 2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww
# usc000stdc 2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww
# usc000sxh8 2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww
# usc000pft9 2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww
# ...

# %%
data_new['country/state'] = data_new['place'].str.rsplit(', ').str[1]

# %%
data_new.head()
# Out:
#                               time   latitude  longitude  depth   mag magType  \
# id
# ak11155107 2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml
# nn00436847 2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml
# ak11151142 2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml
# ak11151135 2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml
# ci37171541 2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml
#
#             nst     gap     dmin     rms net                          updated  \
# id
# ak11155107  NaN     NaN      NaN  0.2900  ak 2014-02-05 19:34:41.515000+00:00
# nn00436847  4.0  171.43  0.34200  0.0247  nn        2014-02-01 01:35:09+00:00
# ak11151142  NaN     NaN      NaN  1.0000  ak 2014-02-01 00:03:53.010000+00:00
# ak11151135  NaN     NaN      NaN  1.0700  ak 2014-01-31 23:41:25.007000+00:00
# ci37171541  6.0  285.00  0.04321  0.2000  ci 2014-02-01 00:13:20.107000+00:00
#
# ...

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120108 entries, ak11155107 to ak11453389
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   time           120108 non-null  datetime64[ns]
#  1   latitude       120108 non-null  float64
#  2   longitude      120108 non-null  float64
#  3   depth          120107 non-null  float64
#  4   mag            120065 non-null  float64
#  5   magType        120065 non-null  object
#  6   nst            59688 non-null   float64
#  7   gap            94935 non-null   float64
#  8   dmin           85682 non-null   float64
#  9   rms            119716 non-null  float64
#  10  net            120108 non-null  object
#  11  updated        120108 non-null  datetime64[ns, UTC]
#  12  place          120108 non-null  object
#  13  type           120108 non-null  object
#  14  country/state  116607 non-null  object
# ...

# %%
# filtered data 
filtered_data = data_earthquake[data_earthquake['mag'] >= 4.0]
filtered_data.head()
# Out:
#                               time  latitude  longitude   depth  mag magType  \
# id
# usc000mqlp 2014-01-31 23:08:03.660   -4.9758   153.9466  110.18  4.2      mb
# usc000mqln 2014-01-31 22:54:32.970  -28.1775  -177.9058   95.84  4.3      mb
# usc000mqls 2014-01-31 22:49:49.740  -23.1192   179.1174  528.34  4.4      mb
# usc000mf1x 2014-01-31 22:19:44.330   51.1569  -178.0910   37.50  4.2      mb
# usc000mqlm 2014-01-31 21:56:44.320   -4.8800   153.8434  112.66  4.3      mb
#
#             nst    gap   dmin   rms net                   updated  \
# id
# usc000mqlp  NaN   98.0  1.940  0.61  us 2014-04-08 01:43:19+00:00
# usc000mqln  NaN  104.0  1.063  1.14  us 2014-04-08 01:43:19+00:00
# usc000mqls  NaN   80.0  5.439  0.95  us 2014-04-08 01:43:19+00:00
# usc000mf1x  NaN    NaN    NaN  0.83  us 2014-04-08 01:43:19+00:00
# usc000mqlm  NaN  199.0  1.808  0.79  us 2014-04-08 01:43:19+00:00
#
#                                            place        type
# id
# ...

# %%
# country/state with highest earthquakes

data_new['country/state'].value_counts().head(10)
# Out:
# country/state
# California     44451
# Alaska         33589
# Oregon          3195
# Nevada          2858
# Washington      2784
# Hawaii          2564
# Puerto Rico     2284
# Indonesia       2120
# Oklahoma        1992
# Montana         1991
# Name: count, dtype: int64

# %%
data_mag_country = data_new[['country/state','mag']]
data_mag_country
# Out:
#            country/state   mag
# id
# ak11155107        Alaska  1.10
# nn00436847        Nevada  1.33
# ak11151142        Alaska  1.30
# ak11151135        Alaska  0.80
# ci37171541        Mexico  1.34
# ...                  ...   ...
# ak11453391        Alaska  3.80
# ak11453395        Alaska  2.40
# nc72358451    California  0.43
# ak11453390        Alaska  0.40
# ak11453389        Alaska  1.60
#
# [120108 rows x 2 columns]

# %%
data_answer_of_countrymag = data_mag_country.groupby('country/state').agg({'mag':'max'}).sort_values('mag', ascending=False)
data_answer_of_countrymag.head(10)
# Out:
#                   mag
# country/state
# Chile             8.2
# Alaska            7.9
# Solomon Islands   7.6
# Papua New Guinea  7.5
# El Salvador       7.3
# Mexico            7.2
# Fiji              7.1
# Indonesia         7.1
# Greece            6.9
# China             6.9

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120108 entries, ak11155107 to ak11453389
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   time           120108 non-null  datetime64[ns]
#  1   latitude       120108 non-null  float64
#  2   longitude      120108 non-null  float64
#  3   depth          120107 non-null  float64
#  4   mag            120065 non-null  float64
#  5   magType        120065 non-null  object
#  6   nst            59688 non-null   float64
#  7   gap            94935 non-null   float64
#  8   dmin           85682 non-null   float64
#  9   rms            119716 non-null  float64
#  10  net            120108 non-null  object
#  11  updated        120108 non-null  datetime64[ns, UTC]
#  12  place          120108 non-null  object
#  13  type           120108 non-null  object
#  14  country/state  116607 non-null  object
# ...

# %%
def is_us_state(name):
    cleaned_name = name.strip().title()  # Ensure title case without strip function
    return cleaned_name in states_usa

# Assuming 'data' is your DataFrame and 'country/state' is the column containing country/state names
boolean_series = data_new['country/state'].dropna().apply(lambda x: is_us_state(x))
boolean_series
# Out:
# id
# ak11155107     True
# nn00436847     True
# ak11151142     True
# ak11151135     True
# ci37171541    False
#               ...
# ak11453391     True
# ak11453395     True
# nc72358451     True
# ak11453390     True
# ak11453389     True
# Name: country/state, Length: 116607, dtype: bool

# %%
states_usa = [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 
    'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 
    'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 
    'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
    'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 
    'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 
    'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 
    'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 
    'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 
    'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'
]
data_new.loc[data_new['country/state'].isin( states_usa),'country/state'] = 'USA'
data_new.head()
# Out:
#                               time   latitude  longitude  depth   mag magType  \
# id
# ak11155107 2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml
# nn00436847 2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml
# ak11151142 2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml
# ak11151135 2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml
# ci37171541 2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml
#
#             nst     gap     dmin     rms net                          updated  \
# id
# ak11155107  NaN     NaN      NaN  0.2900  ak 2014-02-05 19:34:41.515000+00:00
# nn00436847  4.0  171.43  0.34200  0.0247  nn        2014-02-01 01:35:09+00:00
# ak11151142  NaN     NaN      NaN  1.0000  ak 2014-02-01 00:03:53.010000+00:00
# ak11151135  NaN     NaN      NaN  1.0700  ak 2014-01-31 23:41:25.007000+00:00
# ci37171541  6.0  285.00  0.04321  0.2000  ci 2014-02-01 00:13:20.107000+00:00
#
# ...

# %%
def is_us_state(name):
    cleaned_name = name.strip().title()  # Ensure title case without strip function
    return cleaned_name in states_usa

# Assuming 'data' is your DataFrame and 'country/state' is the column containing country/state names
boolean_series = data_new['country/state'].dropna().apply(lambda x: is_us_state(x))
boolean_series
# Out:
# id
# ak11155107    False
# nn00436847    False
# ak11151142    False
# ak11151135    False
# ci37171541    False
#               ...
# ak11453391    False
# ak11453395    False
# nc72358451    False
# ak11453390    False
# ak11453389    False
# Name: country/state, Length: 116607, dtype: bool

# %%
data_new['is_us_state'] = boolean_series
data_new.head()
# Out:
#                               time   latitude  longitude  depth   mag magType  \
# id
# ak11155107 2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml
# nn00436847 2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml
# ak11151142 2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml
# ak11151135 2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml
# ci37171541 2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml
#
#             nst     gap     dmin     rms net                          updated  \
# id
# ak11155107  NaN     NaN      NaN  0.2900  ak 2014-02-05 19:34:41.515000+00:00
# nn00436847  4.0  171.43  0.34200  0.0247  nn        2014-02-01 01:35:09+00:00
# ak11151142  NaN     NaN      NaN  1.0000  ak 2014-02-01 00:03:53.010000+00:00
# ak11151135  NaN     NaN      NaN  1.0700  ak 2014-01-31 23:41:25.007000+00:00
# ci37171541  6.0  285.00  0.04321  0.2000  ci 2014-02-01 00:13:20.107000+00:00
#
# ...

# %%
data_new['country/state'].value_counts().head(10)
# Out:
# country/state
# USA                 96684
# Puerto Rico          2284
# Indonesia            2120
# Papua New Guinea     1356
# Chile                1191
# Japan                1150
# Canada                765
# New Zealand           762
# Philippines           749
# Mexico                677
# Name: count, dtype: int64

# %%
data_answer_of_countrymag = data_mag_country.groupby('country/state').agg({'mag':'max'}).sort_values('mag', ascending=False)
data_answer_of_countrymag.head(10)
# Out:
#                   mag
# country/state
# Chile             8.2
# Alaska            7.9
# Solomon Islands   7.6
# Papua New Guinea  7.5
# El Salvador       7.3
# Mexico            7.2
# Fiji              7.1
# Indonesia         7.1
# Greece            6.9
# China             6.9
